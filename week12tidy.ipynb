# %%
import pandas as pd

# %%
df = pd.read_csv("messy/census.csv")
df
# Out:
#         state  state fips        commodity  \
# 0    US TOTAL          99  FARM OPERATIONS
# 1    US TOTAL          99  FARM OPERATIONS
# 2    US TOTAL          99  FARM OPERATIONS
# 3    US TOTAL          99  FARM OPERATIONS
# 4    US TOTAL          99  FARM OPERATIONS
# ..        ...         ...              ...
# 124  US TOTAL          99         POTATOES
# 125  US TOTAL          99   SWEET POTATOES
# 126  US TOTAL          99   SWEET POTATOES
# 127  US TOTAL          99         ORCHARDS
# 128  US TOTAL          99         ORCHARDS
#
#                                              data item  \
# 0               FARM OPERATIONS - NUMBER OF OPERATIONS
# 1               FARM OPERATIONS - NUMBER OF OPERATIONS
# 2               FARM OPERATIONS - NUMBER OF OPERATIONS
# 3               FARM OPERATIONS - NUMBER OF OPERATIONS
# 4               FARM OPERATIONS - NUMBER OF OPERATIONS
# ..                                                 ...
# ...

# %%
df = df.rename(columns = {"US TOTAL": "us_total",
                         "FARM OPERATIONS": "farm_operations",
                         "FARM OPERATIONS - NUMBER OF OPERATIONS": "farm_operations - number of operations",
                         "AREA OPERATED:(1.0 TO 9.9 ACRES)": "area_operated"})
df
# Out:
#         state  state fips        commodity  \
# 0    US TOTAL          99  FARM OPERATIONS
# 1    US TOTAL          99  FARM OPERATIONS
# 2    US TOTAL          99  FARM OPERATIONS
# 3    US TOTAL          99  FARM OPERATIONS
# 4    US TOTAL          99  FARM OPERATIONS
# ..        ...         ...              ...
# 124  US TOTAL          99         POTATOES
# 125  US TOTAL          99   SWEET POTATOES
# 126  US TOTAL          99   SWEET POTATOES
# 127  US TOTAL          99         ORCHARDS
# 128  US TOTAL          99         ORCHARDS
#
#                                              data item  \
# 0               FARM OPERATIONS - NUMBER OF OPERATIONS
# 1               FARM OPERATIONS - NUMBER OF OPERATIONS
# 2               FARM OPERATIONS - NUMBER OF OPERATIONS
# 3               FARM OPERATIONS - NUMBER OF OPERATIONS
# 4               FARM OPERATIONS - NUMBER OF OPERATIONS
# ..                                                 ...
# ...

# %%
## NAME THE VARIABLES 
melt_df = df.melt(id_vars = "commodity")
melt_df
# Out:
#             commodity variable      value
# 0     FARM OPERATIONS    state   US TOTAL
# 1     FARM OPERATIONS    state   US TOTAL
# 2     FARM OPERATIONS    state   US TOTAL
# 3     FARM OPERATIONS    state   US TOTAL
# 4     FARM OPERATIONS    state   US TOTAL
# ...               ...      ...        ...
# 1156         POTATOES     1997  1,372,458
# 1157   SWEET POTATOES     1997      1,976
# 1158   SWEET POTATOES     1997     80,953
# 1159         ORCHARDS     1997    123,420
# 1160         ORCHARDS     1997        NaN
#
# [1161 rows x 3 columns]

# %%
pew = pd.read_csv("messy/census.csv")
pew
# Out:
#         state  state fips        commodity  \
# 0    US TOTAL          99  FARM OPERATIONS
# 1    US TOTAL          99  FARM OPERATIONS
# 2    US TOTAL          99  FARM OPERATIONS
# 3    US TOTAL          99  FARM OPERATIONS
# 4    US TOTAL          99  FARM OPERATIONS
# ..        ...         ...              ...
# 124  US TOTAL          99         POTATOES
# 125  US TOTAL          99   SWEET POTATOES
# 126  US TOTAL          99   SWEET POTATOES
# 127  US TOTAL          99         ORCHARDS
# 128  US TOTAL          99         ORCHARDS
#
#                                              data item  \
# 0               FARM OPERATIONS - NUMBER OF OPERATIONS
# 1               FARM OPERATIONS - NUMBER OF OPERATIONS
# 2               FARM OPERATIONS - NUMBER OF OPERATIONS
# 3               FARM OPERATIONS - NUMBER OF OPERATIONS
# 4               FARM OPERATIONS - NUMBER OF OPERATIONS
# ..                                                 ...
# ...

# %%
df = df.drop(["state", "state fips"], axis = 1)
df
# Out:
#            commodity                                          data item  \
# 0    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ..               ...                                                ...
# 124         POTATOES                         POTATOES - ACRES HARVESTED
# 125   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 126   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 127         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 128         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                          domain category       2017       2012       2007  \
# ...

# %%
df = df.melt(id_vars=["commodity", "data item", "domain category"],
                              var_name = "year",)
df
# Out:
#            commodity                                          data item  \
# 0    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ..               ...                                                ...
# 640         POTATOES                         POTATOES - ACRES HARVESTED
# 641   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 642   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 643         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 644         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                          domain category  year      value
# ...

# %%
melted_pew = df.melt(id_vars=["commodity", "data item", "domain category"],
                              var_name = "year",
                            value_name = "amount")
melted_pew
# Out:
#             commodity                                          data item  \
# 0     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ...               ...                                                ...
# 1285         POTATOES                         POTATOES - ACRES HARVESTED
# 1286   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 1287   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 1288         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 1289         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                           domain category   year     amount
# ...

# %%
df = df.rename(columns={"domain category": "acres"})
df
# Out:
#            commodity                                          data item  \
# 0    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ..               ...                                                ...
# 640         POTATOES                         POTATOES - ACRES HARVESTED
# 641   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 642   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 643         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 644         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                                    acres  year      value
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   commodity  645 non-null    object
#  1   data item  645 non-null    object
#  2   acres      75 non-null     object
#  3   year       645 non-null    object
#  4   value      616 non-null    object
# dtypes: object(5)
# memory usage: 25.3+ KB

# %%
list(df.columns)
# Out:
# ['commodity', 'data item', 'acres', 'year', 'value']

# %%
df["commodity"].unique()
# Out:
# array(['FARM OPERATIONS', 'AG LAND', 'MACHINERY TOTALS',
#        'COMMODITY TOTALS', 'CROP TOTALS', 'ANIMAL TOTALS',
#        'EXPENSE TOTALS', 'FEED', 'FERTILIZER TOTALS', 'FUELS', 'LABOR',
#        'INTEREST', 'CHEMICAL TOTALS', 'CATTLE', 'HOGS', 'CHICKENS',
#        'CORN', 'WHEAT', 'OATS', 'BARLEY', 'SORGHUM', 'SOYBEANS', 'BEANS',
#        'COTTON', 'TOBACCO', 'HAY & HAYLAGE', 'RICE', 'SUNFLOWER',
#        'SUGARBEETS', 'SUGARCANE', 'PEANUTS', 'VEGETABLE TOTALS',
#        'POTATOES', 'SWEET POTATOES', 'ORCHARDS'], dtype=object)

# %%
df
# Out:
#            commodity                                          data item  \
# 0    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4    FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ..               ...                                                ...
# 640         POTATOES                         POTATOES - ACRES HARVESTED
# 641   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 642   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 643         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 644         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#                                    acres  year      value
# ...

# %%
df[["commodity_type", "data item"]] = df["data item"].str.split("-",n=1, expand = True)
df
# Out:
#            commodity                                    data item  \
# 0    FARM OPERATIONS                         NUMBER OF OPERATIONS
# 1    FARM OPERATIONS                         NUMBER OF OPERATIONS
# 2    FARM OPERATIONS                         NUMBER OF OPERATIONS
# 3    FARM OPERATIONS                         NUMBER OF OPERATIONS
# 4    FARM OPERATIONS                         NUMBER OF OPERATIONS
# ..               ...                                          ...
# 640         POTATOES                              ACRES HARVESTED
# 641   SWEET POTATOES               OPERATIONS WITH AREA HARVESTED
# 642   SWEET POTATOES                              ACRES HARVESTED
# 643         ORCHARDS   OPERATIONS WITH AREA BEARING & NON-BEARING
# 644         ORCHARDS                  ACRES BEARING & NON-BEARING
#
#                                    acres  year      value    commodity_type
# 0                                    NaN  2017  2,042,220  FARM OPERATIONS
# ...
